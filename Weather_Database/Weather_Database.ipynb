# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b02c17c8a755f4cb5e5080799e5bd79c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | changping
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | sibiti
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | carpinteria
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | gat
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | moose factory
# Processing Record 14 of Set 1 | mountain home
# Processing Record 15 of Set 1 | burgeo
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | nanortalik
# Processing Record 23 of Set 1 | niagara falls
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | cayenne
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | ola
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | mackay
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | abha
# Processing Record 34 of Set 1 | kangaatsiaq
# Processing Record 35 of Set 1 | ponta delgada
# Processing Record 36 of Set 1 | shelburne
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | warwick
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | isiolo
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | bilibino
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | kilakarai
# Processing Record 48 of Set 1 | birjand
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | nantucket
# Processing Record 1 of Set 2 | gasa
# Processing Record 2 of Set 2 | russell
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | port augusta
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | sosnovo-ozerskoye
# Processing Record 7 of Set 2 | aras
# Processing Record 8 of Set 2 | tazovskiy
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | truckee
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | santo antonio do ica
# Processing Record 21 of Set 2 | acarau
# Processing Record 22 of Set 2 | saint-joseph
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | marzuq
# Processing Record 25 of Set 2 | lasa
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | sioux lookout
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | yuli
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | srednekolymsk
# Processing Record 36 of Set 2 | dwarka
# Processing Record 37 of Set 2 | igrim
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | alexandria
# Processing Record 42 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | ganzhou
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | vardo
# Processing Record 50 of Set 2 | nemuro
# Processing Record 1 of Set 3 | zeltweg
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | winnipeg
# Processing Record 4 of Set 3 | dakar
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | mogadishu
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | danesti
# Processing Record 9 of Set 3 | shingu
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | norman wells
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | yulara
# Processing Record 14 of Set 3 | kashi
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | caravelas
# Processing Record 17 of Set 3 | colares
# Processing Record 18 of Set 3 | banda aceh
# Processing Record 19 of Set 3 | korla
# Processing Record 20 of Set 3 | sal rei
# Processing Record 21 of Set 3 | surgut
# Processing Record 22 of Set 3 | port hawkesbury
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | onega
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | hualmay
# Processing Record 27 of Set 3 | zelenoborskiy
# Processing Record 28 of Set 3 | puerto quijarro
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | memaliaj
# Processing Record 31 of Set 3 | kiruna
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | puerto ayora
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | opuwo
# Processing Record 43 of Set 3 | palmeira das missoes
# Processing Record 44 of Set 3 | adrar
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | diffa
# Processing Record 48 of Set 3 | viedma
# Processing Record 49 of Set 3 | arlit
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | tairua
# Processing Record 2 of Set 4 | san juan
# Processing Record 3 of Set 4 | bereda
# Processing Record 4 of Set 4 | mwinilunga
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | ulaanbaatar
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | bolivar
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | yangliuqing
# Processing Record 11 of Set 4 | alugan
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 4 | deputatskiy
# Processing Record 15 of Set 4 | tigil
# Processing Record 16 of Set 4 | stornoway
# Processing Record 17 of Set 4 | inta
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | baherden
# Processing Record 21 of Set 4 | port lincoln
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | sobolevo
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | palmer
# Processing Record 27 of Set 4 | port keats
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | matamoros
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | syracuse
# Processing Record 32 of Set 4 | yumen
# Processing Record 33 of Set 4 | seoul
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | envira
# Processing Record 36 of Set 4 | catalao
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | great yarmouth
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 4 | tianpeng
# Processing Record 43 of Set 4 | dzerzhinskoye
# Processing Record 44 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | salinas
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | half moon bay
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | eastbourne
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 5 | nisia floresta
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | fare
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | camana
# Processing Record 11 of Set 5 | nalut
# Processing Record 12 of Set 5 | paramonga
# Processing Record 13 of Set 5 | freeport
# Processing Record 14 of Set 5 | juneau
# Processing Record 15 of Set 5 | paysandu
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | lata
# Processing Record 18 of Set 5 | konya
# Processing Record 19 of Set 5 | bua yai
# Processing Record 20 of Set 5 | anloga
# Processing Record 21 of Set 5 | rouvroy
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | cidreira
# Processing Record 24 of Set 5 | tucurui
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | listvyagi
# Processing Record 27 of Set 5 | poum
# Processing Record 28 of Set 5 | rong kwang
# Processing Record 29 of Set 5 | portland
# Processing Record 30 of Set 5 | siteki
# Processing Record 31 of Set 5 | pacific grove
# Processing Record 32 of Set 5 | noumea
# Processing Record 33 of Set 5 | livingston
# Processing Record 34 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 35 of Set 5 | betafo
# Processing Record 36 of Set 5 | prince rupert
# Processing Record 37 of Set 5 | antequera
# Processing Record 38 of Set 5 | itarema
# Processing Record 39 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 40 of Set 5 | masumbwe
# Processing Record 41 of Set 5 | hailar
# Processing Record 42 of Set 5 | hami
# Processing Record 43 of Set 5 | caluquembe
# Processing Record 44 of Set 5 | kyshtovka
# Processing Record 45 of Set 5 | chaykovskaya
# Processing Record 46 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 5 | bac lieu
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 5 | kiama
# Processing Record 1 of Set 6 | lazaro cardenas
# Processing Record 2 of Set 6 | awjilah
# Processing Record 3 of Set 6 | alta floresta
# Processing Record 4 of Set 6 | muzhi
# Processing Record 5 of Set 6 | fortuna
# Processing Record 6 of Set 6 | piltene
# Processing Record 7 of Set 6 | eyl
# Processing Record 8 of Set 6 | kottagudem
# Processing Record 9 of Set 6 | kiunga
# Processing Record 10 of Set 6 | ixtapa
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | saint-philippe
# Processing Record 13 of Set 6 | auki
# Processing Record 14 of Set 6 | puerto escondido
# Processing Record 15 of Set 6 | la rioja
# Processing Record 16 of Set 6 | atambua
# Processing Record 17 of Set 6 | riyadh
# Processing Record 18 of Set 6 | vichy
# Processing Record 19 of Set 6 | bom jesus
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | camacha
# Processing Record 23 of Set 6 | bomet
# Processing Record 24 of Set 6 | kailua
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | roald
# Processing Record 27 of Set 6 | madanapalle
# Processing Record 28 of Set 6 | nagornyy
# Processing Record 29 of Set 6 | aksarka
# Processing Record 30 of Set 6 | abilene
# Processing Record 31 of Set 6 | skibbereen
# Processing Record 32 of Set 6 | labytnangi
# Processing Record 33 of Set 6 | taunggyi
# Processing Record 34 of Set 6 | atka
# City not found. Skipping...
# Processing Record 35 of Set 6 | payo
# Processing Record 36 of Set 6 | bakaly
# Processing Record 37 of Set 6 | kelvington
# Processing Record 38 of Set 6 | shestakovo
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | tiksi
# Processing Record 41 of Set 6 | haines junction
# Processing Record 42 of Set 6 | whitehorse
# Processing Record 43 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 6 | port macquarie
# Processing Record 45 of Set 6 | san isidro
# Processing Record 46 of Set 6 | porto murtinho
# Processing Record 47 of Set 6 | khanpur
# Processing Record 48 of Set 6 | moussoro
# Processing Record 49 of Set 6 | coihaique
# Processing Record 50 of Set 6 | touros
# Processing Record 1 of Set 7 | vytegra
# Processing Record 2 of Set 7 | abu dhabi
# Processing Record 3 of Set 7 | la uribe
# City not found. Skipping...
# Processing Record 4 of Set 7 | mao
# Processing Record 5 of Set 7 | machico
# Processing Record 6 of Set 7 | graaff-reinet
# Processing Record 7 of Set 7 | mangrol
# Processing Record 8 of Set 7 | lac du bonnet
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | wajima
# Processing Record 11 of Set 7 | ossora
# Processing Record 12 of Set 7 | oeiras
# Processing Record 13 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 7 | saint albans
# Processing Record 15 of Set 7 | daru
# Processing Record 16 of Set 7 | kahului
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | pajapan
# Processing Record 19 of Set 7 | port moresby
# Processing Record 20 of Set 7 | baruun-urt
# Processing Record 21 of Set 7 | kokstad
# Processing Record 22 of Set 7 | bobrovytsya
# Processing Record 23 of Set 7 | sharjah
# Processing Record 24 of Set 7 | mar del plata
# Processing Record 25 of Set 7 | jacareacanga
# Processing Record 26 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 7 | san vicente
# Processing Record 28 of Set 7 | mnogovershinnyy
# Processing Record 29 of Set 7 | namatanai
# Processing Record 30 of Set 7 | yakima
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | santiago
# Processing Record 33 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 7 | antalaha
# Processing Record 35 of Set 7 | seminole
# Processing Record 36 of Set 7 | aksu
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | atikokan
# Processing Record 39 of Set 7 | corner brook
# Processing Record 40 of Set 7 | cabedelo
# Processing Record 41 of Set 7 | mizan teferi
# Processing Record 42 of Set 7 | vestmannaeyjar
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | lebu
# Processing Record 46 of Set 7 | talnakh
# Processing Record 47 of Set 7 | saint george
# Processing Record 48 of Set 7 | pietersburg
# Processing Record 49 of Set 7 | shchors
# Processing Record 50 of Set 7 | pemangkat
# Processing Record 1 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 2 of Set 8 | agropoli
# Processing Record 3 of Set 8 | boguchany
# Processing Record 4 of Set 8 | salta
# Processing Record 5 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 8 | shirokiy
# Processing Record 7 of Set 8 | agirish
# Processing Record 8 of Set 8 | kotelnich
# Processing Record 9 of Set 8 | port hedland
# Processing Record 10 of Set 8 | iracoubo
# Processing Record 11 of Set 8 | durusu
# Processing Record 12 of Set 8 | morant bay
# Processing Record 13 of Set 8 | dafeng
# Processing Record 14 of Set 8 | namtsy
# Processing Record 15 of Set 8 | broken hill
# Processing Record 16 of Set 8 | ceuta
# Processing Record 17 of Set 8 | new norfolk
# Processing Record 18 of Set 8 | kardla
# Processing Record 19 of Set 8 | barreirinha
# Processing Record 20 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 8 | kerouane
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 8 | orlik
# Processing Record 25 of Set 8 | ostrovnoy
# Processing Record 26 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 27 of Set 8 | kysyl-syr
# Processing Record 28 of Set 8 | dzhebariki-khaya
# Processing Record 29 of Set 8 | butembo
# Processing Record 30 of Set 8 | ugoofaaru
# Processing Record 31 of Set 8 | port-de-bouc
# Processing Record 32 of Set 8 | lindsay
# Processing Record 33 of Set 8 | sakakah
# Processing Record 34 of Set 8 | tayu
# Processing Record 35 of Set 8 | pangai
# Processing Record 36 of Set 8 | maningrida
# Processing Record 37 of Set 8 | bandar-e anzali
# Processing Record 38 of Set 8 | maragogi
# Processing Record 39 of Set 8 | luau
# Processing Record 40 of Set 8 | ipiau
# Processing Record 41 of Set 8 | longyearbyen
# Processing Record 42 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 8 | tyukalinsk
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | porto novo
# Processing Record 46 of Set 8 | campbell river
# Processing Record 47 of Set 8 | launceston
# Processing Record 48 of Set 8 | tura
# Processing Record 49 of Set 8 | marawi
# Processing Record 50 of Set 8 | hastings
# Processing Record 1 of Set 9 | san carlos del zulia
# Processing Record 2 of Set 9 | pasni
# Processing Record 3 of Set 9 | neuquen
# Processing Record 4 of Set 9 | galesong
# Processing Record 5 of Set 9 | shiyan
# Processing Record 6 of Set 9 | champerico
# Processing Record 7 of Set 9 | changji
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 9 | yurginskoye
# Processing Record 10 of Set 9 | grand gaube
# Processing Record 11 of Set 9 | ponazyrevo
# Processing Record 12 of Set 9 | sayat
# Processing Record 13 of Set 9 | saint-georges
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | porto walter
# Processing Record 16 of Set 9 | basco
# Processing Record 17 of Set 9 | batagay
# Processing Record 18 of Set 9 | visnes
# Processing Record 19 of Set 9 | serabu
# Processing Record 20 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 9 | ust-nera
# Processing Record 22 of Set 9 | amga
# Processing Record 23 of Set 9 | lincoln
# Processing Record 24 of Set 9 | magadan
# Processing Record 25 of Set 9 | kalabo
# Processing Record 26 of Set 9 | bobcaygeon
# Processing Record 27 of Set 9 | warrington
# Processing Record 28 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 9 | valjala
# City not found. Skipping...
# Processing Record 30 of Set 9 | wampusirpi
# City not found. Skipping...
# Processing Record 31 of Set 9 | jardim
# Processing Record 32 of Set 9 | chepareria
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | general jose eduvigis diaz
# Processing Record 35 of Set 9 | hanna
# Processing Record 36 of Set 9 | upington
# Processing Record 37 of Set 9 | sarevere
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | kvarkeno
# Processing Record 40 of Set 9 | manjacaze
# Processing Record 41 of Set 9 | samarai
# Processing Record 42 of Set 9 | denpasar
# Processing Record 43 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 9 | karratha
# Processing Record 45 of Set 9 | stephenville
# Processing Record 46 of Set 9 | asfi
# Processing Record 47 of Set 9 | carutapera
# Processing Record 48 of Set 9 | show low
# Processing Record 49 of Set 9 | rawson
# Processing Record 50 of Set 9 | zeven
# Processing Record 1 of Set 10 | nagato
# Processing Record 2 of Set 10 | dzilam gonzalez
# Processing Record 3 of Set 10 | calama
# Processing Record 4 of Set 10 | magistralnyy
# Processing Record 5 of Set 10 | upata
# Processing Record 6 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 10 | jijiga
# Processing Record 8 of Set 10 | hengshui
# Processing Record 9 of Set 10 | tabas
# Processing Record 10 of Set 10 | nurota
# Processing Record 11 of Set 10 | thinadhoo
# Processing Record 12 of Set 10 | zharkent
# Processing Record 13 of Set 10 | praia
# Processing Record 14 of Set 10 | winkler
# Processing Record 15 of Set 10 | goderich
# Processing Record 16 of Set 10 | nanakuli
# Processing Record 17 of Set 10 | bathsheba
# Processing Record 18 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 20 of Set 10 | chalmette
# Processing Record 21 of Set 10 | emerald
# Processing Record 22 of Set 10 | camara de lobos
# Processing Record 23 of Set 10 | taua
# Processing Record 24 of Set 10 | coralville
# Processing Record 25 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 10 | wittmund
# Processing Record 27 of Set 10 | assai
# Processing Record 28 of Set 10 | fez
# Processing Record 29 of Set 10 | altayskoye
# Processing Record 30 of Set 10 | pontal do parana
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | ambilobe
# Processing Record 33 of Set 10 | minab
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | ca mau
# Processing Record 36 of Set 10 | alice springs
# Processing Record 37 of Set 10 | mandurah
# Processing Record 38 of Set 10 | tarko-sale
# Processing Record 39 of Set 10 | ribeira do pombal
# Processing Record 40 of Set 10 | kuntaur
# Processing Record 41 of Set 10 | deep river
# Processing Record 42 of Set 10 | colon
# Processing Record 43 of Set 10 | laguna
# Processing Record 44 of Set 10 | naze
# Processing Record 45 of Set 10 | mentougou
# Processing Record 46 of Set 10 | kupang
# Processing Record 47 of Set 10 | teya
# Processing Record 48 of Set 10 | sambava
# Processing Record 49 of Set 10 | matara
# Processing Record 50 of Set 10 | turayf
# Processing Record 1 of Set 11 | victor harbor
# Processing Record 2 of Set 11 | vila velha
# Processing Record 3 of Set 11 | khingansk
# Processing Record 4 of Set 11 | general pico
# Processing Record 5 of Set 11 | pitimbu
# Processing Record 6 of Set 11 | dryden
# Processing Record 7 of Set 11 | marsa matruh
# Processing Record 8 of Set 11 | nevel
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 11 | chinsali
# Processing Record 13 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 11 | tyrma
# Processing Record 15 of Set 11 | ta khmau
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | at-bashi
# Processing Record 18 of Set 11 | luancheng
# Processing Record 19 of Set 11 | le port
# Processing Record 20 of Set 11 | minanga
# Processing Record 21 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 11 | berlevag
# Processing Record 23 of Set 11 | shimoda
# Processing Record 24 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 11 | plettenberg bay
# Processing Record 26 of Set 11 | norwich
# Processing Record 27 of Set 11 | kuryk
# Processing Record 28 of Set 11 | lunino
# Processing Record 29 of Set 11 | aransas pass
# Processing Record 30 of Set 11 | belaya gora
# Processing Record 31 of Set 11 | yerbogachen
# Processing Record 32 of Set 11 | muros
# Processing Record 33 of Set 11 | rudbar
# Processing Record 34 of Set 11 | tempoal
# City not found. Skipping...
# Processing Record 35 of Set 11 | kirovskiy
# Processing Record 36 of Set 11 | kapoeta
# Processing Record 37 of Set 11 | camalu
# Processing Record 38 of Set 11 | elk point
# Processing Record 39 of Set 11 | tual
# Processing Record 40 of Set 11 | henties bay
# Processing Record 41 of Set 11 | bisira
# Processing Record 42 of Set 11 | heyang
# Processing Record 43 of Set 11 | abu ghosh
# Processing Record 44 of Set 11 | alekseyevka
# Processing Record 45 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 11 | sain alto
# Processing Record 48 of Set 11 | esperance
# Processing Record 49 of Set 11 | banikoara
# Processing Record 50 of Set 11 | santa margherita ligure
# Processing Record 1 of Set 12 | pilar
# Processing Record 2 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 3 of Set 12 | yashkul
# Processing Record 4 of Set 12 | dingle
# Processing Record 5 of Set 12 | elbistan
# Processing Record 6 of Set 12 | mendoza
# Processing Record 7 of Set 12 | tadine
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | coxim
# Processing Record 10 of Set 12 | walvis bay
# Processing Record 11 of Set 12 | agramonte
# Processing Record 12 of Set 12 | sovetskaya gavan
# Processing Record 13 of Set 12 | chapais
# Processing Record 14 of Set 12 | minot
# Processing Record 15 of Set 12 | rock sound
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | boyolangu
# Processing Record 18 of Set 12 | razdolinsk
# Processing Record 19 of Set 12 | thaba-tseka
# Processing Record 20 of Set 12 | gilgit
# Processing Record 21 of Set 12 | beringovskiy
# Processing Record 22 of Set 12 | novyy nekouz
# Processing Record 23 of Set 12 | minokamo
# Processing Record 24 of Set 12 | zehdenick
# Processing Record 25 of Set 12 | tautira
# Processing Record 26 of Set 12 | bocanda
# Processing Record 27 of Set 12 | fort nelson
# Processing Record 28 of Set 12 | sechura
# Processing Record 29 of Set 12 | vanimo
# Processing Record 30 of Set 12 | diebougou
# Processing Record 31 of Set 12 | mankera
# Processing Record 32 of Set 12 | santa cruz
# Processing Record 33 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 12 | labuhan
# Processing Record 35 of Set 12 | hargeysa
# Processing Record 36 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 12 | laukaa
# Processing Record 39 of Set 12 | mayumba
# Processing Record 40 of Set 12 | guacimo
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | jishou
# Processing Record 43 of Set 12 | synya
# Processing Record 44 of Set 12 | corpus christi
# Processing Record 45 of Set 12 | serro
# Processing Record 46 of Set 12 | kansay
# City not found. Skipping...
# Processing Record 47 of Set 12 | hohhot
# Processing Record 48 of Set 12 | tahe
# Processing Record 49 of Set 12 | iwanai
# Processing Record 50 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 1 of Set 13 | coahuayana
# Processing Record 2 of Set 13 | tuban
# Processing Record 3 of Set 13 | ventersburg
# Processing Record 4 of Set 13 | natitingou
# Processing Record 5 of Set 13 | bundaberg
# Processing Record 6 of Set 13 | agde
# Processing Record 7 of Set 13 | abapo
# Processing Record 8 of Set 13 | mahajanga
# Processing Record 9 of Set 13 | omboue
# Processing Record 10 of Set 13 | azangaro
# Processing Record 11 of Set 13 | adelanto
# Processing Record 12 of Set 13 | yamada
# Processing Record 13 of Set 13 | kabare
# Processing Record 14 of Set 13 | oranjemund
# Processing Record 15 of Set 13 | ust-karsk
# Processing Record 16 of Set 13 | gurlan
# Processing Record 17 of Set 13 | gizo
# Processing Record 18 of Set 13 | panticeu
# Processing Record 19 of Set 13 | qasigiannguit
# Processing Record 20 of Set 13 | sosenskiy
# Processing Record 21 of Set 13 | san policarpo
# Processing Record 22 of Set 13 | malakal
# Processing Record 23 of Set 13 | arman
# Processing Record 24 of Set 13 | gashua
# Processing Record 25 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 26 of Set 13 | orebro
# Processing Record 27 of Set 13 | urucara
# Processing Record 28 of Set 13 | hukuntsi
# Processing Record 29 of Set 13 | alghero
# Processing Record 30 of Set 13 | namibe
# Processing Record 31 of Set 13 | sibu
# Processing Record 32 of Set 13 | tiznit
# Processing Record 33 of Set 13 | henderson
# Processing Record 34 of Set 13 | toucheng
# Processing Record 35 of Set 13 | umm lajj
# Processing Record 36 of Set 13 | zhigansk
# Processing Record 37 of Set 13 | tongren
# Processing Record 38 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 13 | pochutla
# Processing Record 40 of Set 13 | jacqueville
# Processing Record 41 of Set 13 | saurimo
# Processing Record 42 of Set 13 | roma
# Processing Record 43 of Set 13 | palana
# Processing Record 44 of Set 13 | leningradskiy
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | dorverden
# Processing Record 47 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 13 | husavik
# Processing Record 49 of Set 13 | jakar
# Processing Record 50 of Set 13 | vaxjo
# Processing Record 1 of Set 14 | pangnirtung
# Processing Record 2 of Set 14 | moa
# Processing Record 3 of Set 14 | manta
# Processing Record 4 of Set 14 | luganville
# Processing Record 5 of Set 14 | koszeg
# Processing Record 6 of Set 14 | zheleznodorozhnyy
# Processing Record 7 of Set 14 | labuan
# Processing Record 8 of Set 14 | dukat
# Processing Record 9 of Set 14 | chulym
# Processing Record 10 of Set 14 | atar
# Processing Record 11 of Set 14 | manicore
# Processing Record 12 of Set 14 | simcoe
# Processing Record 13 of Set 14 | alassio
# Processing Record 14 of Set 14 | grindavik
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | okhotsk
# Processing Record 17 of Set 14 | bonga
# Processing Record 18 of Set 14 | dohar
# Processing Record 19 of Set 14 | keetmanshoop
# Processing Record 20 of Set 14 | hokitika
# Processing Record 21 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 22 of Set 14 | madang
# Processing Record 23 of Set 14 | jackson
# Processing Record 24 of Set 14 | bendigo
# Processing Record 25 of Set 14 | wanaka
# Processing Record 26 of Set 14 | oranjestad
# Processing Record 27 of Set 14 | pirenopolis
# Processing Record 28 of Set 14 | constitucion
# Processing Record 29 of Set 14 | huarmey
# Processing Record 30 of Set 14 | fukue
# Processing Record 31 of Set 14 | lenine
# Processing Record 32 of Set 14 | saint-augustin
# Processing Record 33 of Set 14 | traverse city
# Processing Record 34 of Set 14 | jaguarari
# Processing Record 35 of Set 14 | sukhumi
# Processing Record 36 of Set 14 | feldru
# Processing Record 37 of Set 14 | jiamusi
# Processing Record 38 of Set 14 | cookeville
# Processing Record 39 of Set 14 | umm kaddadah
# Processing Record 40 of Set 14 | lashio
# Processing Record 41 of Set 14 | waipawa
# Processing Record 42 of Set 14 | flin flon
# Processing Record 43 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 44 of Set 14 | mana
# Processing Record 45 of Set 14 | dunedin
# Processing Record 46 of Set 14 | westport
# Processing Record 47 of Set 14 | wembley
# Processing Record 48 of Set 14 | malidong
# Processing Record 49 of Set 14 | seymchan
# Processing Record 50 of Set 14 | innisfail
# Processing Record 1 of Set 15 | harwich
# Processing Record 2 of Set 15 | kaberamaido
# Processing Record 3 of Set 15 | meulaboh
# Processing Record 4 of Set 15 | fecamp
# Processing Record 5 of Set 15 | wajir
# Processing Record 6 of Set 15 | huambo
# Processing Record 7 of Set 15 | lamar
# Processing Record 8 of Set 15 | inhambane
# Processing Record 9 of Set 15 | manggar
# Processing Record 10 of Set 15 | shaoguan
# Processing Record 11 of Set 15 | nioro
# Processing Record 12 of Set 15 | kirkland lake
# Processing Record 13 of Set 15 | savannah bight
# Processing Record 14 of Set 15 | gamba
# Processing Record 15 of Set 15 | cerrito
# Processing Record 16 of Set 15 | ninohe
# Processing Record 17 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 15 | turangi
# Processing Record 19 of Set 15 | ampanihy
# Processing Record 20 of Set 15 | oriximina
# Processing Record 21 of Set 15 | armeria
# Processing Record 22 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 15 | fria
# Processing Record 24 of Set 15 | dabakala
# Processing Record 25 of Set 15 | arkhangelsk
# Processing Record 26 of Set 15 | coro
# Processing Record 27 of Set 15 | broome
# Processing Record 28 of Set 15 | beira
# Processing Record 29 of Set 15 | bayanday
# Processing Record 30 of Set 15 | marigot
# Processing Record 31 of Set 15 | fort morgan
# Processing Record 32 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 15 | tarakan
# Processing Record 35 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 15 | vestmanna
# Processing Record 37 of Set 15 | muheza
# Processing Record 38 of Set 15 | constantine
# Processing Record 39 of Set 15 | farafenni
# Processing Record 40 of Set 15 | puerto del rosario
# Processing Record 41 of Set 15 | kampene
# Processing Record 42 of Set 15 | lagunas
# Processing Record 43 of Set 15 | marakkanam
# Processing Record 44 of Set 15 | nadvoitsy
# Processing Record 45 of Set 15 | snezhnogorsk
# Processing Record 46 of Set 15 | gimli
# Processing Record 47 of Set 15 | fojnica
# Processing Record 48 of Set 15 | gonbad-e qabus
# Processing Record 49 of Set 15 | grand baie
# Processing Record 50 of Set 15 | chartres
# Processing Record 1 of Set 16 | muisne
# Processing Record 2 of Set 16 | cervo
# Processing Record 3 of Set 16 | ayan
# Processing Record 4 of Set 16 | kegayli
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Cherskiy  68.75  161.30      4.33        94         100        5.26
# 1     Changping  40.22  116.22     53.01        33           0        4.47
# 2         Vaini -21.20 -175.20     75.20        88          75        8.05
# 3        Sibiti  -3.68   13.35     69.73        99         100        3.33
# 4        Dikson  73.51   80.55     19.63        98          96        9.06
# ..          ...    ...     ...       ...       ...         ...         ...
# 676  Grand Baie -20.02   57.58     66.99        69          28        1.99
# 677    Chartres  48.42    1.50     63.00        96         100       13.00
# 678      Muisne   0.60  -80.03     82.40        78          40       13.87
# 679       Cervo  43.67   -7.41     69.01        92          16       10.00
# 680        Ayan  56.45  138.17     26.82        98         100       21.03
#
#     Country Current Description
# 0        RU     overcast clouds
# 1        CN           clear sky
# 2        TO       broken clouds
# 3        CG     overcast clouds
# 4        RU     overcast clouds
# ..      ...                 ...
# 676      MU    scattered clouds
# 677      FR     overcast clouds
# 678      EC    scattered clouds
# 679      ES          few clouds
# 680      RU                snow
#
# [681 rows x 9 columns]

# %%
#reordering dataframe 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cherskiy      RU  68.75  161.30      4.33        94         100
# 1    Changping      CN  40.22  116.22     53.01        33           0
# 2        Vaini      TO -21.20 -175.20     75.20        88          75
# 3       Sibiti      CG  -3.68   13.35     69.73        99         100
# 4       Dikson      RU  73.51   80.55     19.63        98          96
# 5   Butaritari      KI   3.07  172.79     81.79        78           1
# 6  Carpinteria      US  34.40 -119.52     84.00        59          69
# 7       Hobart      AU -42.88  147.33     53.60        87          75
# 8      Qaanaaq      GL  77.48  -69.36      1.08        74           0
# 9      Ushuaia      AR -54.80  -68.30     57.20        58          75
#
#    Wind Speed Current Description
# 0        5.26     overcast clouds
# 1        4.47           clear sky
# 2        8.05       broken clouds
# 3        3.33     overcast clouds
# 4        9.06     overcast clouds
# 5       10.60           clear sky
# 6        3.60       broken clouds
# 7        4.70       broken clouds
# 8        7.56           clear sky
# 9       11.41          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
